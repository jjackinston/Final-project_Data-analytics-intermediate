# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Reading my csv Data

# %% [markdown]
# These data come from the web page of the Bureau of Transportation Statistics. these data have been downloaded as CSV and are added as a file in COLAB.

# %% [markdown]
# ###**Project**: Analysis of national transportation data to enable the Strategical deployment of the Trucking company Carl and MaJ Logistics and Transportation

# %%
missing_values = ['n/a','na','NaN','--','(null)']

# %%
data=pd.read_csv('/content/transportation_states.csv',na_values=missing_values)

# %%
data.head()
# Out:
#   Unnamed: 0 Chained 2012 Value (millions of dollars) Unnamed: 2 Unnamed: 3  \
# 0        NaN                                     2012       2013       2014
# 1    Alabama                                  254,678    254,973    262,113
# 2     Alaska                                   69,774     65,554     70,364
# 3    Arizona                                  187,589    191,561    194,236
# 4   Arkansas                                  149,443    150,788    151,100
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0       2015       2016       2017       2018
# 1    267,676    270,952    271,894    279,873
# 2     71,921     71,610     72,279     72,595
# 3    195,739    193,994    190,836    195,643
# 4    147,210    146,981    148,777    153,578
#
#    Chained 2012 Value Percent Change   Unnamed: 9  ...  Unnamed: 47  \
# 0                             2012.0  2013.000000  ...         2016
# 1                                NaN     0.001162  ...       86,849
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0 Chained 2012 Value (millions of dollars) Unnamed: 2  \
# 47       Virginia                                  299,796    294,169
# 48     Washington                                  420,316    422,985
# 49  West Virginia                                   81,499     72,534
# 50      Wisconsin                                  336,000    338,310
# 51        Wyoming                                   57,584     57,391
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 47    299,918    301,473    298,919    298,795    307,111
# 48    439,196    438,772    432,607    430,669    442,666
# 49     72,950     71,379     68,828     70,776     74,975
# 50    345,052    342,384    340,415    344,912    353,799
# 51     58,184     57,867     55,202     55,876     59,270
#
#     Chained 2012 Value Percent Change  Unnamed: 9  ...  Unnamed: 47  \
# 47                                NaN   -0.018770  ...       48,922
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 57 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unnamed: 0                                51 non-null     object
#  1   Chained 2012 Value (millions of dollars)  52 non-null     object
#  2   Unnamed: 2                                52 non-null     object
#  3   Unnamed: 3                                52 non-null     object
#  4   Unnamed: 4                                52 non-null     object
#  5   Unnamed: 5                                52 non-null     object
#  6   Unnamed: 6                                52 non-null     object
#  7   Unnamed: 7                                52 non-null     object
#  8   Chained 2012 Value Percent Change         1 non-null      float64
#  9   Unnamed: 9                                52 non-null     float64
# ...

# %%
data.shape
# Out:
# (52, 57)

# %%
data.dtypes
# Out:
# Unnamed: 0                                   object
# Chained 2012 Value (millions of dollars)     object
# Unnamed: 2                                   object
# Unnamed: 3                                   object
# Unnamed: 4                                   object
# Unnamed: 5                                   object
# Unnamed: 6                                   object
# Unnamed: 7                                   object
# Chained 2012 Value Percent Change           float64
# Unnamed: 9                                  float64
# Unnamed: 10                                 float64
# Unnamed: 11                                 float64
# Unnamed: 12                                 float64
# Unnamed: 13                                 float64
# Unnamed: 14                                 float64
# Current Value (millions of dollars)          object
# Unnamed: 16                                  object
# Unnamed: 17                                  object
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Chained 2012 Value (millions of dollars)', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Chained 2012 Value Percent Change', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Current Value (millions of dollars)', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Current Value Percent Change', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Tons (thousands)', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Tons Percent Change',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Ton Miles (millions)', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
# ...

# %% [markdown]
# **###DATA CLEANING**

# %% [markdown]
# This operation consists of cleaning and organizing the necessary data in such a way as to facilitate its exploration, analysis and visualization.

# %% [markdown]
# *Drop columns*

# %%
data.drop(['Chained 2012 Value (millions of dollars)','Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Chained 2012 Value Percent Change','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14' ], axis=1,inplace=True)

# %%
data
# Out:
#               Unnamed: 0 Current Value (millions of dollars) Unnamed: 16  \
# 0                    NaN                                2012        2013
# 1                Alabama                             254,678     257,684
# 2                 Alaska                              69,774      66,362
# 3                Arizona                             187,589     193,620
# 4               Arkansas                             149,443     152,645
# 5             California                           2,014,266   2,062,316
# 6               Colorado                             196,777     199,716
# 7            Connecticut                             209,780     212,304
# 8               Delaware                              55,271      53,614
# 9   District of Columbia                               6,426      12,603
# 10               Florida                             577,191     573,023
# 11               Georgia                             526,852     533,775
# ...

# %% [markdown]
# *Rename columns*

# %%
data.rename(columns={
        'Unnamed: 0':'States'}, inplace=True)

# %%
data.head()
# Out:
#      States Current Value (millions of dollars) Unnamed: 16 Unnamed: 17  \
# 0       NaN                                2012        2013        2014
# 1   Alabama                             254,678     257,684     270,579
# 2    Alaska                              69,774      66,362      69,321
# 3   Arizona                             187,589     193,620     199,882
# 4  Arkansas                             149,443     152,645     157,124
#
#   Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0        2015        2016        2017        2018
# 1     261,466     259,459     271,079     289,624
# 2      53,225      49,341      54,763      61,472
# 3     196,695     194,695     197,634     208,668
# 4     142,013     136,883     144,380     153,361
#
#    Current Value Percent Change  Unnamed: 23  ...  Unnamed: 47  Unnamed: 48  \
# 0                        2012.0  2013.000000  ...         2016         2017
# ...

# %% [markdown]
# *Dealing with the missing values*

# %%
data.isnull().sum()
# Out:
# States                                  1
# Current Value (millions of dollars)     0
# Unnamed: 16                             0
# Unnamed: 17                             0
# Unnamed: 18                             0
# Unnamed: 19                             0
# Unnamed: 20                             0
# Unnamed: 21                             0
# Current Value Percent Change           51
# Unnamed: 23                             0
# Unnamed: 24                             0
# Unnamed: 25                             0
# Unnamed: 26                             0
# Unnamed: 27                             0
# Unnamed: 28                             0
# Tons (thousands)                        0
# Unnamed: 30                             0
# Unnamed: 31                             0
# Unnamed: 32                             0
# Unnamed: 33                             0
# Unnamed: 34                             0
# Unnamed: 35                             0
# ...

# %% [markdown]
# *Droppng rows with NaN*

# %%
data.dropna(subset=['States'],inplace=True)

# %%
data.head()
# Out:
#        States Current Value (millions of dollars) Unnamed: 16 Unnamed: 17  \
# 1     Alabama                             254,678     257,684     270,579
# 2      Alaska                              69,774      66,362      69,321
# 3     Arizona                             187,589     193,620     199,882
# 4    Arkansas                             149,443     152,645     157,124
# 5  California                           2,014,266   2,062,316   2,118,265
#
#   Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 1     261,466     259,459     271,079     289,624
# 2      53,225      49,341      54,763      61,472
# 3     196,695     194,695     197,634     208,668
# 4     142,013     136,883     144,380     153,361
# 5   2,030,120   2,002,354   2,093,092   2,224,253
#
#    Current Value Percent Change  Unnamed: 23  ...  Unnamed: 47  Unnamed: 48  \
# 1                           NaN     0.011806  ...       86,849       88,328
# ...

# %% [markdown]
# *Dropping columns with NaN*

# %%
data.drop(['Current Value Percent Change','Current Value Percent Change','Tons Percent Change','Ton Miles Percent Change'], axis=1,inplace=True)

# %%
data.head()
# Out:
#        States Current Value (millions of dollars) Unnamed: 16 Unnamed: 17  \
# 1     Alabama                             254,678     257,684     270,579
# 2      Alaska                              69,774      66,362      69,321
# 3     Arizona                             187,589     193,620     199,882
# 4    Arkansas                             149,443     152,645     157,124
# 5  California                           2,014,266   2,062,316   2,118,265
#
#   Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  Unnamed: 23  Unnamed: 24  \
# 1     261,466     259,459     271,079     289,624     0.011806     0.050039
# 2      53,225      49,341      54,763      61,472    -0.048904     0.044591
# 3     196,695     194,695     197,634     208,668     0.032149     0.032343
# 4     142,013     136,883     144,380     153,361     0.021430     0.029340
# 5   2,030,120   2,002,354   2,093,092   2,224,253     0.023855     0.027129
#
# ...

# %%
data.isnull().sum()
# Out:
# States                                 0
# Current Value (millions of dollars)    0
# Unnamed: 16                            0
# Unnamed: 17                            0
# Unnamed: 18                            0
# Unnamed: 19                            0
# Unnamed: 20                            0
# Unnamed: 21                            0
# Unnamed: 23                            0
# Unnamed: 24                            0
# Unnamed: 25                            0
# Unnamed: 26                            0
# Unnamed: 27                            0
# Unnamed: 28                            0
# Tons (thousands)                       0
# Unnamed: 30                            0
# Unnamed: 31                            0
# Unnamed: 32                            0
# Unnamed: 33                            0
# Unnamed: 34                            0
# Unnamed: 35                            0
# Unnamed: 37                            0
# Unnamed: 38                            0
# ...

# %% [markdown]
# Rename the columns of the cleaning data

# %%
data.rename(columns={
        'Current Value (millions of dollars)':'Value_2012 (millions of dollars)','Unnamed: 16':'Value_2013 (millions of dollars)','Unnamed: 17':'Value_2014 (millions of dollars)','Unnamed: 18':'Value_2015 (millions of dollars)','Unnamed: 19':'Value_2016 (millions of dollars)','Unnamed: 20':'Value_2017 (millions of dollars)','Unnamed: 21':'Value_2018 (millions of dollars)'}, inplace=True)

# %%
data
# Out:
#                   States Value_2012 (millions of dollars)  \
# 1                Alabama                          254,678
# 2                 Alaska                           69,774
# 3                Arizona                          187,589
# 4               Arkansas                          149,443
# 5             California                        2,014,266
# 6               Colorado                          196,777
# 7            Connecticut                          209,780
# 8               Delaware                           55,271
# 9   District of Columbia                            6,426
# 10               Florida                          577,191
# 11               Georgia                          526,852
# 12                Hawaii                           30,218
# 13                 Idaho                           60,741
# 14              Illinois                        1,019,064
# 15               Indiana                          442,305
# ...

# %%
data.rename(columns={
        'Unnamed: 23':'Value Percent change 2013','Unnamed: 24':'Value Percent change 2014','Unnamed: 25':'Value Percent change 2015','Unnamed: 26':'Value Percent change 2016','Unnamed: 27':'Value Percent change 2017','Unnamed: 28':'Value Percent change 2018'}, inplace=True)

# %%
data.head()
# Out:
#        States Value_2012 (millions of dollars)  \
# 1     Alabama                          254,678
# 2      Alaska                           69,774
# 3     Arizona                          187,589
# 4    Arkansas                          149,443
# 5  California                        2,014,266
#
#   Value_2013 (millions of dollars) Value_2014 (millions of dollars)  \
# 1                          257,684                          270,579
# 2                           66,362                           69,321
# 3                          193,620                          199,882
# 4                          152,645                          157,124
# 5                        2,062,316                        2,118,265
#
#   Value_2015 (millions of dollars) Value_2016 (millions of dollars)  \
# 1                          261,466                          259,459
# 2                           53,225                           49,341
# ...

# %%
data.rename(columns={
        'Ton Miles (millions)':'Ton 2012 (millions)','Unnamed: 44':'Ton 2013 (millions)','Unnamed: 45':'Ton 2014 (millions)','Unnamed: 46':'Ton 2015 (millions)','Unnamed: 47':'Ton 2016 (millions)','Unnamed: 48':'Ton 2017 (millions)','Unnamed: 49':'Ton 2017 (millions)'}, inplace=True)

# %%
data.head()
# Out:
#        States Value_2012 (millions of dollars)  \
# 1     Alabama                          254,678
# 2      Alaska                           69,774
# 3     Arizona                          187,589
# 4    Arkansas                          149,443
# 5  California                        2,014,266
#
#   Value_2013 (millions of dollars) Value_2014 (millions of dollars)  \
# 1                          257,684                          270,579
# 2                           66,362                           69,321
# 3                          193,620                          199,882
# 4                          152,645                          157,124
# 5                        2,062,316                        2,118,265
#
#   Value_2015 (millions of dollars) Value_2016 (millions of dollars)  \
# 1                          261,466                          259,459
# 2                           53,225                           49,341
# ...

# %%
data.rename(columns={
        'Unnamed: 51':'Ton Percent change 2013','Unnamed: 52':'Ton Percent change 2014','Unnamed: 53':'Ton Percent change 2015','Unnamed: 54':'Ton Percent change 2016','Unnamed: 55':'Ton Percent change 2017','Unnamed: 56':'Ton Percent change 2018'}, inplace=True)

# %%
data.dtypes
# Out:
# States                               object
# Value_2012 (millions of dollars)     object
# Value_2013 (millions of dollars)     object
# Value_2014 (millions of dollars)     object
# Value_2015 (millions of dollars)     object
# Value_2016 (millions of dollars)     object
# Value_2017 (millions of dollars)     object
# Value_2018 (millions of dollars)     object
# Value Percent change 2013           float64
# Value Percent change 2014           float64
# Value Percent change 2015           float64
# Value Percent change 2016           float64
# Value Percent change 2017           float64
# Value Percent change 2018           float64
# Tons (thousands)                     object
# Unnamed: 30                          object
# Unnamed: 31                          object
# Unnamed: 32                          object
# Unnamed: 33                          object
# Unnamed: 34                          object
# Unnamed: 35                          object
# ...

# %%
data
# Out:
#                   States Value_2012 (millions of dollars)  \
# 1                Alabama                          254,678
# 2                 Alaska                           69,774
# 3                Arizona                          187,589
# 4               Arkansas                          149,443
# 5             California                        2,014,266
# 6               Colorado                          196,777
# 7            Connecticut                          209,780
# 8               Delaware                           55,271
# 9   District of Columbia                            6,426
# 10               Florida                          577,191
# 11               Georgia                          526,852
# 12                Hawaii                           30,218
# 13                 Idaho                           60,741
# 14              Illinois                        1,019,064
# 15               Indiana                          442,305
# ...

# %%
data
# Out:
#                   States Value_2012 (millions of dollars)  \
# 1                Alabama                          254,678
# 2                 Alaska                           69,774
# 3                Arizona                          187,589
# 4               Arkansas                          149,443
# 5             California                        2,014,266
# 6               Colorado                          196,777
# 7            Connecticut                          209,780
# 8               Delaware                           55,271
# 9   District of Columbia                            6,426
# 10               Florida                          577,191
# 11               Georgia                          526,852
# 12                Hawaii                           30,218
# 13                 Idaho                           60,741
# 14              Illinois                        1,019,064
# 15               Indiana                          442,305
# ...

# %% [markdown]
# Converting my data into Integer

# %% [markdown]
# Some data to be analyzed must be converted to Integer or float. TO do so, we eliminate all the space and after convert the data in integer

# %%
data['Value_2013 (millions of dollars)']=data['Value_2013 (millions of dollars)'].str.replace(',','').astype(int)

# %%
data['Value_2014 (millions of dollars)']=data['Value_2014 (millions of dollars)'].str.replace(',','').astype(int)

# %%
data['Value_2015 (millions of dollars)']=data['Value_2015 (millions of dollars)'].str.replace(',','').astype(int)

# %%
data['Value_2016 (millions of dollars)']=data['Value_2016 (millions of dollars)'].str.replace(',','').astype(int)

# %%
data['Value_2017 (millions of dollars)']=data['Value_2017 (millions of dollars)'].str.replace(',','').astype(int)

# %%
data['Value_2018 (millions of dollars)']=data['Value_2018 (millions of dollars)'].str.replace(',','').astype(int)

# %%
data['Ton 2012 (millions)']=data['Ton 2012 (millions)'].str.replace(',','').astype(int)

# %%
data['Ton 2013 (millions)']=data['Ton 2013 (millions)'].str.replace(',','').astype(int)

# %%
data['Ton 2014 (millions)']=data['Ton 2014 (millions)'].str.replace(',','').astype(int)

# %%
data['Ton 2015 (millions)']=data['Ton 2015 (millions)'].str.replace(',','').astype(int)

# %%
data['Ton 2016 (millions)']=data['Ton 2016 (millions)'].str.replace(',','').astype(int)

# %%
data['Ton 2018 (millions)']=data['Ton 2018 (millions)'].str.replace(',','').astype(int)

# %%
data['Value_2012 (millions of dollars)']=data['Value_2012 (millions of dollars)'].str.replace(',','').astype(int)

# %%
data.dtypes
# Out:
# States                               object
# Value_2012 (millions of dollars)      int64
# Value_2013 (millions of dollars)      int64
# Value_2014 (millions of dollars)      int64
# Value_2015 (millions of dollars)      int64
# Value_2016 (millions of dollars)      int64
# Value_2017 (millions of dollars)      int64
# Value_2018 (millions of dollars)      int64
# Value Percent change 2013           float64
# Value Percent change 2014           float64
# Value Percent change 2015           float64
# Value Percent change 2016           float64
# Value Percent change 2017           float64
# Value Percent change 2018           float64
# Tons (thousands)                     object
# Unnamed: 30                          object
# Unnamed: 31                          object
# Unnamed: 32                          object
# Unnamed: 33                          object
# Unnamed: 34                          object
# Unnamed: 35                          object
# ...

# %% [markdown]
# ###ANALYSIS and visualization OF MY CLEANING DATA

# %% [markdown]
# Through this section we try to analyze the States to consider and to avoid to establish our transport company. This analysis is done at several levels:
# -The 10 best states in terms of revenue and commodity
# -The 10 worst states in terms of revenue and commodity
# -The 10 Most Improved States in the Industry

# %%
amount_mean_per_State=data[['Value_2012 (millions of dollars)','Value_2013 (millions of dollars)','Value_2014 (millions of dollars)','Value_2015 (millions of dollars)','Value_2016 (millions of dollars)','Value_2017 (millions of dollars)','Value_2018 (millions of dollars)']].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
amount_mean_per_State
# Out:
# Value_2013 (millions of dollars)    352413.196078
# Value_2014 (millions of dollars)    362261.294118
# Value_2015 (millions of dollars)    335511.529412
# Value_2016 (millions of dollars)    326020.980392
# Value_2017 (millions of dollars)    343000.411765
# Value_2018 (millions of dollars)    369489.254902
# dtype: float64

# %%
amount_mean_per_State.plot(kind="bar",title="Average amount(millions)/State 2012-2018")

# %%
data['sum_of_value']=data['Value_2012 (millions of dollars)']+ data['Value_2013 (millions of dollars)']+ data['Value_2014 (millions of dollars)']+ data['Value_2015 (millions of dollars)']+ data['Value_2016 (millions of dollars)']+ data['Value_2017 (millions of dollars)']+ data['Value_2018 (millions of dollars)']

# %%
data
# Out:
#                   States  Value_2012 (millions of dollars)  \
# 1                Alabama                            254678
# 2                 Alaska                             69774
# 3                Arizona                            187589
# 4               Arkansas                            149443
# 5             California                           2014266
# 6               Colorado                            196777
# 7            Connecticut                            209780
# 8               Delaware                             55271
# 9   District of Columbia                              6426
# 10               Florida                            577191
# 11               Georgia                            526852
# 12                Hawaii                             30218
# 13                 Idaho                             60741
# 14              Illinois                           1019064
# 15               Indiana                            442305
# ...

# %%
data['mean_of_value_per_state']=data['sum_of_value']/7

# %%
data
# Out:
#                   States  Value_2012 (millions of dollars)  \
# 1                Alabama                            254678
# 2                 Alaska                             69774
# 3                Arizona                            187589
# 4               Arkansas                            149443
# 5             California                           2014266
# 6               Colorado                            196777
# 7            Connecticut                            209780
# 8               Delaware                             55271
# 9   District of Columbia                              6426
# 10               Florida                            577191
# 11               Georgia                            526852
# 12                Hawaii                             30218
# 13                 Idaho                             60741
# 14              Illinois                           1019064
# 15               Indiana                            442305
# ...

# %%
best_states = data[['States','sum_of_value']].sort_values('sum_of_value',ascending=False).head(10)

# %%
best_states
# Out:
#           States  sum_of_value
# 44         Texas      16790226
# 5     California      14544666
# 14      Illinois       7067799
# 33      New York       5505364
# 39  Pennsylvania       4786227
# 36          Ohio       4569084
# 31    New Jersey       4462401
# 23      Michigan       4292969
# 10       Florida       4001240
# 11       Georgia       3864544

# %%
best_states.plot(kind="bar",title="sum of value per State")

# %%
worst_states =data[['States','sum_of_value']].sort_values('sum_of_value',ascending=False).tail(10)

# %%
worst_states
# Out:
#                   States  sum_of_value
# 42          South Dakota        389408
# 20                 Maine        382335
# 40          Rhode Island        374068
# 51               Wyoming        362899
# 8               Delaware        361262
# 27               Montana        353098
# 30         New Hampshire        319509
# 46               Vermont        256869
# 12                Hawaii        197155
# 9   District of Columbia         85547

# %%
data.dtypes
# Out:
# States                               object
# Value_2012 (millions of dollars)      int64
# Value_2013 (millions of dollars)      int64
# Value_2014 (millions of dollars)      int64
# Value_2015 (millions of dollars)      int64
# Value_2016 (millions of dollars)      int64
# Value_2017 (millions of dollars)      int64
# Value_2018 (millions of dollars)      int64
# Value Percent change 2013           float64
# Value Percent change 2014           float64
# Value Percent change 2015           float64
# Value Percent change 2016           float64
# Value Percent change 2017           float64
# Value Percent change 2018           float64
# Tons (thousands)                     object
# Unnamed: 30                          object
# Unnamed: 31                          object
# Unnamed: 32                          object
# Unnamed: 33                          object
# Unnamed: 34                          object
# Unnamed: 35                          object
# ...

# %% [markdown]
# ###Analyisis of the value percent change

# %%
data['sum_of_PC']=data['Value Percent change 2013']+ data['Value Percent change 2014']+ data['Value Percent change 2015']+ data['Value Percent change 2016']+ data['Value Percent change 2017']+ data['Value Percent change 2018']

# %%
data.head()

# %%
data['mean_of_PC']=data['sum_of_PC']/6

# %%
data

# %%
Best_change =data[['States','mean_of_PC']].sort_values('mean_of_PC',ascending=False).head(10)

# %%
Best_change # allows us to identify and to follow those  potential State in the future

# %%
Best_change.plot(kind="bar",title="Value Percent change per State")

# %%
worst_change =data[['States','mean_of_PC']].sort_values('mean_of_PC',ascending=False).tail(10)

# %%
worst_change

# %%
worst_change.plot(kind="bar",title="Value Percent change per State")

# %% [markdown]
# ###Analysis of the ton transported

# %%
data['sum_of_ton']=data['Ton 2012 (millions)']+ data['Ton 2013 (millions)']+ data['Ton 2014 (millions)']+ data['Ton 2015 (millions)']+ data['Ton 2016 (millions)']

# %%
data
# Out:
#                   States  Value_2012 (millions of dollars)  \
# 1                Alabama                            254678
# 2                 Alaska                             69774
# 3                Arizona                            187589
# 4               Arkansas                            149443
# 5             California                           2014266
# 6               Colorado                            196777
# 7            Connecticut                            209780
# 8               Delaware                             55271
# 9   District of Columbia                              6426
# 10               Florida                            577191
# 11               Georgia                            526852
# 12                Hawaii                             30218
# 13                 Idaho                             60741
# 14              Illinois                           1019064
# 15               Indiana                            442305
# ...

# %%
Best_state_ton= data[['States','sum_of_ton']].sort_values('sum_of_ton',ascending=False).head(10)

# %%
Best_state_ton
# Out:
#           States  sum_of_ton
# 44         Texas     3052590
# 51       Wyoming     2594004
# 5     California     1699713
# 19     Louisiana     1118937
# 14      Illinois     1078151
# 35  North Dakota      945370
# 24     Minnesota      827914
# 39  Pennsylvania      716979
# 36          Ohio      597767
# 16          Iowa      591969

# %%
Best_state_ton.plot(kind="bar",title="Value of ton of commodity")

# %%
Best_state_ton
# Out:
#           States  sum_of_ton
# 44         Texas     3052590
# 51       Wyoming     2594004
# 5     California     1699713
# 19     Louisiana     1118937
# 14      Illinois     1078151
# 35  North Dakota      945370
# 24     Minnesota      827914
# 39  Pennsylvania      716979
# 36          Ohio      597767
# 16          Iowa      591969

# %%
Worst_states_ton=data[['States','sum_of_ton']].sort_values('sum_of_ton',ascending=False).tail(10)

# %%
Worst_states_ton
# Out:
#                   States  sum_of_ton
# 21              Maryland      115810
# 29                Nevada      108005
# 22         Massachusetts      102822
# 20                 Maine       71529
# 46               Vermont       25763
# 8               Delaware       23630
# 30         New Hampshire       23064
# 12                Hawaii       21960
# 40          Rhode Island       19407
# 9   District of Columbia        4685

# %% [markdown]
# ###Conclusion

# %% [markdown]
# At first glance, the States with high revenue generation in the country-level cargo transportation sector are scattered across the country. Considering those data, we can recommend the installation of the company in the states of Illinois which represent the center of the Best States for Revenue, for the best improved States.
